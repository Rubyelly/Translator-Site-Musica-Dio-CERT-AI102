# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubyelly/Translator-Site-Musica-Dio-CERT-AI102/blob/main/Translator_Music.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests python-docx

# %%
import requests
from docx import Document
import os
subscription_key = 'SUA_CHAVE_AQUI'
endpoint = 'https://api.cognitive.microsofttranslator.com/'
location = 'eastus2'
language_destination = 'pt-br'

def translator_text(text, target_language):
 path = '/translate'
 constructed_url = endpoint + path
 headrs = {
  'Ocp-Apim-Subscription-Key': subscription_key,
  'Ocp-Apim-Subscription-Region': location,
  'Content-type': 'application/json',
   'X-ClientTraceId': str(os.urandom(16))
 }

 body = [{
  'text': text
 }]
 params = {
  'api-version': '3.0',
  'from': 'en',
  'to': target_language

 }
 request = requests.post(constructed_url, headers=headrs, json=body, params=params)
 response = request.json()
 return response[0]["translations"][0]["text"]

# %%
translator_text('Messenger of ages, Carried on the wings of second birth', target_language)
# Out:
# 'Mensageiro de eras, Carregado nas asas do segundo nascimento'

# %%
def translate_document(path):
  document = Document(path)
  full_text = []
  for paragraph in document.paragraphs:
    translated_text = translator_text(paragraph.text, language_destination)
    full_text.append(translated_text)

  translate_doc = Document()
  for line in full_text:
    print(line)
    translate_doc.add_paragraph(line)
  path_translated = path.replace('.docx', f'_{language_destination}.docx')
  translate_doc.save(path_translated)
  return path_translated

input_file = '/content/Ghost Ship - Theocracy.docx'
translate_document(input_file)
# Out:
# Navio Fantasma
# Canção de Teocracia
#
# Mensageiro das eras
# Carregado nas asas do segundo nascimento
# Para os segredos silenciosos da terra
# Geração de justiça
# Hino para o senso de propósito que perdemos
# Nós nos elevamos e contamos o custo
# Nós somos aqueles que os outros deixaram para trás
# Sopro de vida dos quatro ventos
# Veja esses ossos da morte agora marcharem novamente
# Pague o flautista
# Aqui vamos nós
# Recebi um bilhete para uma viagem só de ida
# Mate a víbora
# Venha seguir, mesmo que você seja comum
# Há um lugar para você aqui
# Levante a âncora
# Todos a bordo, como o capitão chama Seus desajustados
# Este navio fantasma
# Sai para sacudir o mundo
# Vamos!
# Partir para a jornada
# Junte-se a nós enquanto navegamos em mar aberto
# Para a grande aventura — Segue-Me
# Todo o mundo é indesejado
# Suba a bordo e deixe sua escuridão para trás
# Desesperado para contar, redimir o tempo
# Nós somos os fantasmas despertados para a luz
# ...
